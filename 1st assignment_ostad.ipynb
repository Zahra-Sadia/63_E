# %% [markdown]
# <a href="https://colab.research.google.com/github/Zahra-Sadia/63_E/blob/main/1st%20assignment_ostad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#prb:1
number = int(input("Enter a number: "))
if number % 2 == 0:
    print("Even number")
else:
    print("Odd number.")
# Out:
# Enter a number: 3
# Odd number.

# %%
# Prb:2
x = int(input("Enter first number: "))
y = int(input("Enter second number: "))
op = input("Enter operator: ")

if op == "+":
    print("Answer =", x + y)
elif op == "-":
    print("Answer =", x - y)
elif op == "*":
    print("Answer =", x * y)
elif op == "/":
    if y != 0:
        print("Answer =", x / y)
    else:
        print("not allowed")
else:
    print("Invalid")
# Out:
# Enter first number: 2
# Enter second number: 3
# Enter operator: +
# Answer = 5

# %%
# Prb:3
sum = 0
for i in range(2, 101, 2):
    sum = sum + i
print(sum)
# Out:
# 2550
